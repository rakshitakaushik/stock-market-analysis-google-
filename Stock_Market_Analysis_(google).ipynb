# %% [markdown]
# <a href="https://colab.research.google.com/github/rakshitakaushik/stock-market-analysis-google-/blob/main/Stock_Market_Analysis_(google).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas_datareader.data as web
import datetime
import matplotlib.pyplot as plt

# %%
google.to_csv('Google_stock.csv')

# %%
start = datetime.datetime(2021,1,1) #1st Jan
end   = datetime.datetime(2022,5,1 )#1st May

# %%
google = web.DataReader("GOOGL",'yahoo',start,end)

#GOOGL is the name of the stock
#yahoo is form where we seached
#followed by start and end date

# %%
#google stock data
google.head()
# Out:
#                  High        Low       Open      Close    Volume  Adj Close
# Date
# 2020-12-31  87.875000  86.804497  86.863503  87.632004  21070000  87.632004
# 2021-01-04  88.124496  85.357002  88.000000  86.306503  37324000  86.306503
# 2021-01-05  87.341499  85.845001  86.254501  87.002502  20360000  87.002502
# 2021-01-06  87.198502  84.805000  85.013000  86.143997  46588000  86.143997
# 2021-01-07  88.890999  86.337997  86.337997  88.717003  41936000  88.717003

# %%
#Stock price visualization
google['Open'].plot(label = 'GOOGL Open price')
google['Close'].plot(label = 'GOOGL Close price')
google['High'].plot(label = 'GOOGL High price')
google['Low'].plot(label = 'GOOGL Low price')
plt.legend()
plt.title('Google Stock Price')
plt.ylabel('Stock Price')
plt.show()

# %%
#Volume traded
google['Volume'].plot()
plt.title('Volume Traded')
# Out:
# Text(0.5, 1.0, 'Volume Traded')

# %%
#to find max
google['Volume'].argmax()
# Out:
# 274

# %%
google.iloc[[google['Volume'].argmax()]]
# Out:
#                   High         Low    Open  Close     Volume  Adj Close
# Date
# 2022-02-02  151.546494  145.522507  151.25  148.0  123200000      148.0

# %%
#Market cap
google['Total Traded']=google['Open']*google['Volume']

# %%
google.head()
# Out:
#                  High        Low       Open      Close    Volume  Adj Close  \
# Date
# 2020-12-31  87.875000  86.804497  86.863503  87.632004  21070000  87.632004
# 2021-01-04  88.124496  85.357002  88.000000  86.306503  37324000  86.306503
# 2021-01-05  87.341499  85.845001  86.254501  87.002502  20360000  87.002502
# 2021-01-06  87.198502  84.805000  85.013000  86.143997  46588000  86.143997
# 2021-01-07  88.890999  86.337997  86.337997  88.717003  41936000  88.717003
#
#             Total Traded
# Date
# 2020-12-31  1.830214e+09
# 2021-01-04  3.284512e+09
# 2021-01-05  1.756142e+09
# 2021-01-06  3.960586e+09
# 2021-01-07  3.620670e+09

# %%
google['Total Traded'].plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
google['Total Traded'].argmax()
# Out:
# 274

# %%
google.iloc[[google['Total Traded'].argmax()]]
# Out:
#                   High         Low    Open  Close     Volume  Adj Close  \
# Date
# 2022-02-02  151.546494  145.522507  151.25  148.0  123200000      148.0
#
#             Total Traded
# Date
# 2022-02-02  1.863400e+10

# %%
#moving Average
google['Open'].plot()
google['MA10']=google['Open'].rolling(50).mean()
google['MA10'].plot(label='MA10')
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
#Daily Percentage Change
#rt=pt/pt-1 -1
google['Returns']=(google['Close']/google['Close'].shift(1))-1

# %%
google.head()
# Out:
#                  High        Low       Open      Close    Volume  Adj Close  \
# Date
# 2020-12-31  87.875000  86.804497  86.863503  87.632004  21070000  87.632004
# 2021-01-04  88.124496  85.357002  88.000000  86.306503  37324000  86.306503
# 2021-01-05  87.341499  85.845001  86.254501  87.002502  20360000  87.002502
# 2021-01-06  87.198502  84.805000  85.013000  86.143997  46588000  86.143997
# 2021-01-07  88.890999  86.337997  86.337997  88.717003  41936000  88.717003
#
#             Total Traded  MA10   Returns
# Date
# 2020-12-31  1.830214e+09   NaN       NaN
# 2021-01-04  3.284512e+09   NaN -0.015126
# 2021-01-05  1.756142e+09   NaN  0.008064
# 2021-01-06  3.960586e+09   NaN -0.009868
# 2021-01-07  3.620670e+09   NaN  0.029869

# %%
google['Returns'].argmax()
# Out:
# 274

# %%
google.iloc[[google['Returns'].argmax()]]
# Out:
#                   High         Low    Open  Close     Volume  Adj Close  \
# Date
# 2022-02-02  151.546494  145.522507  151.25  148.0  123200000      148.0
#
#             Total Traded        MA10   Returns
# Date
# 2022-02-02  1.863400e+10  141.626389  0.075238
